# %%
from numpy import *
from matplotlib.pyplot import *

a = 8

x = linspace(0,1,301)
y = exp(-a*(1-x)**2)

plot(x,y, color='black', linewidth=2)
xlabel(r'$x$', fontsize=16)
ylabel(r'$\varphi(x)$', fontsize=16)
xlim(0,1)
ylim(0,1)
savefig('plik.pdf')
show()
